# %% [markdown]
# **By:** *Ahmed Sharaf*

# %% [markdown]
# Probability Concepts, Indepdenece and Random Variables
#
# In this Task you will use python to study the following topics:
#
# - How to simulate random experiment outcomes using numpy arrays.
# - How to estimate the probability of an event using the relative frequency approach.
# - Simulate independent events.
# - Calculate arthemitic mean, sample variance, and sample standard deviation for a dataset.
# - Calculate covariance and correlation coeffecient of two random variables.

# %% [markdown]
# # First: you should run this cell

# %%
# Make all numpy available via shorter 'np' prefix
import numpy as np

# matplotlib library
import matplotlib.pyplot as plt

import pandas as pd

# %% [markdown]
# # Problem 1
#
# Use numpy to simulate the vector outcomes for repeating the following random experiments $1000$ times and use the relative frequency to compute the probability of the corresponding events:
#
# 1. **Experiment:** Flipping a fair coin, **Event:** A head occurs.
#
# Observe how changing the number of repetition affects the computed probabilities.
#
# **Hints:**
# - Use [numpy.random.randint](https://numpy.org/doc/stable/reference/random/generated/numpy.random.randint.html) or [numpy.random.choice](https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html) to simulate the experiment.
# - Other useful functions [numpy.arange](https://numpy.org/doc/stable/reference/generated/numpy.arange.html), [numpy.cumsum](https://numpy.org/doc/stable/reference/generated/numpy.cumsum.html), [numpy.sum](https://numpy.org/doc/stable/reference/generated/numpy.sum.html), and [matplotlib.pyplot.plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
#type your code here:
n_size = [10 ,50 , 100 , 500 , 1000 , 50000]
p = []
for n in n_size:
    Coin = np.random.randint(2, size=n)
    relative_freq = np.count_nonzero(Coin) / len(Coin)
    p.append(relative_freq)
    print(f"n = {n} , p(e) = {relative_freq:.5f}")

plt.plot(n_size ,p )  
plt.axhline(y=0.5, color='y')
plt.show()
# Out:
# n = 10 , p(e) = 0.30000
# n = 50 , p(e) = 0.52000
# n = 100 , p(e) = 0.45000
# n = 500 , p(e) = 0.50400
# n = 1000 , p(e) = 0.48500
# n = 50000 , p(e) = 0.49940

# %% [markdown]
# 2. **Experiment:** Rolling a fair die, **Event:** Number 5 occurs.

# %%
#type your code here:
n_size2 = [10 ,50 , 100 , 500 , 1000 , 50000]
p2 = []
for n in n_size2:
    dice_rolls  = np.random.randint(1, 7, size=n)
    relative_freq = np.count_nonzero(dice_rolls  == 5) / len(dice_rolls )
    p2.append(relative_freq)
    print(f"n = {n} , p(e) = {relative_freq:.5f}")

plt.plot(n_size2 , p2 )  
plt.axhline(y=1/6, color='y')
plt.show()
# Out:
# n = 10 , p(e) = 0.30000
# n = 50 , p(e) = 0.14000
# n = 100 , p(e) = 0.14000
# n = 500 , p(e) = 0.16400
# n = 1000 , p(e) = 0.15200
# n = 50000 , p(e) = 0.16848

# %% [markdown]
# 3. **Experiment:** Rolling a fair die, **Event:** A number greater than 3 occurs.

# %%
#type your code here:
n_size3 = [10 ,50 , 100 , 500 , 1000 , 50000]
p3 = []
for n in n_size3:
    dice_rolls  = np.random.randint(1, 7, size=n)
    relative_freq = np.count_nonzero(dice_rolls  > 3) / len(dice_rolls )
    p3.append(relative_freq)
    print(f"n = {n} , p(e) = {relative_freq:.5f}")

plt.plot(n_size3 , p3 )  
plt.axhline(y=3/6, color='y')
plt.show()
# Out:
# n = 10 , p(e) = 0.30000
# n = 50 , p(e) = 0.42000
# n = 100 , p(e) = 0.48000
# n = 500 , p(e) = 0.49000
# n = 1000 , p(e) = 0.51800
# n = 50000 , p(e) = 0.50168

# %% [markdown]
# 4. **Experiment:** Rolling two fair dice, **Event:** Sum of two dice equal 5.

# %%
#type your code here:
n_size4 = [10 ,50 , 100 , 500 , 1000 , 50000]
p4 = []
for n in n_size4:
    dice_rolls  = np.random.randint(1, 7, size=(n,2))
    sums = np.sum(dice_rolls, axis=1)
    relative_freq = np.count_nonzero(sums == 5) / len(dice_rolls )
    p4.append(relative_freq)
    print(f"n = {n} , p(e) = {relative_freq:.5f}")

plt.plot(n_size4 , p4 )  
plt.axhline(y=4/36, color='y')
plt.show()
# Out:
# n = 10 , p(e) = 0.00000
# n = 50 , p(e) = 0.14000
# n = 100 , p(e) = 0.13000
# n = 500 , p(e) = 0.08800
# n = 1000 , p(e) = 0.11800
# n = 50000 , p(e) = 0.11276

# %% [markdown]
# # Problem 2
#
# Simulate the experiment of tossing $1000$ times a coin with probability of **head (coded as $1$) equal to $0.4$** and probability of **tail (coded as $0$) equal to $0.6$**. How can you check if the simulation of the experiment of been running as expected.
#
# **Hint**: Use [matplotlib.pyplot.hist¶
# ](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html)

# %%
#type your code here:
n_size =1000
coin_p=np.random.choice([0,1] , size = n_size , p=[0.6,0.4])
tail_count = np.count_nonzero(coin_p == 0)
head_count = np.count_nonzero(coin_p == 1)

plt.hist(coin_p)
plt.show()

# %% [markdown]
# # Problem 3: Independence
#
# Use NumPy to create simulations and compute **empirical  probability** for the following outcomes. Compare the results with the **theoretical probability**.
#
# 1. Two fair coin flips produce exactly two heads

# %%
#type your code here:
n_s= 100000
head = 0
p = []
for n in range(n_s):
    Coin_flips = np.random.randint(0,2,2)
    if np.sum(Coin_flips)==2:
        head += 1
    
emp_pro = head / n_s
theoritical_pro = 0.25

print((emp_pro  - theoritical_pro ))
# Out:
# 0.0005800000000000249

# %% [markdown]
# 2. Three fair coin flips produce exactly one head

# %%
#type your code here:
n_s= 100000
head = 0
p = []
for n in range(n_s):
    Coin_flips = np.random.randint(0,2,3)
    if np.sum(Coin_flips)==1:
        head += 1
    
emp_pro = head / n_s
theoritical_pro = 3/8

print((emp_pro  - theoritical_pro ))
# Out:
# -0.0007599999999999829

# %% [markdown]
# 3. Three biased coin flips with P(H) = 0.6 produce exactly one head

# %%
#type your code here:
n_s= 100000
head = 0
p = []
for n in range(n_s):
    
    Coin_flips= np.random.choice([0,1] , size = n_size , p=[0.4,0.6])
    if np.sum(Coin_flips)==1:
        head += 1
    
emp_pro = head / n_s
theoretical_pro = 3 * 0.6 * (0.4**2)

print((emp_pro  - theoritical_pro ))
# Out:
# -0.375

# %% [markdown]
# # Problem 4:Random Variables Statistical Tools
# Simulate Rolling a fair die $1000$ times. Then calculate the following:
#
# - Sample mean
# - Sample variance
# - Sample standard deviation
#
# Compare the results with the theoretical probability.

# %%
#type your code here:
n_roll_die =1000
die = np.random.choice([1, 2, 3, 4, 5, 6], size=n_roll_die)
mean_die = np.mean(die)
variance_die = np.var(die)
std_die = np.std(die)
print(f"Sample mean: {mean_die:}")
print(f"Sample variance: {variance_die:}")
print(f"Sample standard deviation:{std_die:}")

theoretical_mean = 3.5
theoretical_variance = (35/12)
theoretical_std = np.sqrt(theoretical_variance)
print(theoretical_mean)
print(theoretical_variance)
print(theoretical_std)
# Out:
# Sample mean: 3.484
# Sample variance: 2.869744
# Sample standard deviation:1.6940318769137728
# 3.5
# 2.9166666666666665
# 1.707825127659933

# %% [markdown]
# # Problem 5: Correlation and Covariance
#
# The CSV file includes a hourly/daily summary for Szeged, Hungary area, between 2006 and 2016. After inspecting the data:
#
# - Calculate the covariance and correlation coeffecient between temperature and apparent temperature
# - Calculate the covariance and correlation coeffecient between temperature and humidity

# %%
df = pd.read_csv('weatherHistory.csv')
temperature = df['Temperature (C)'].to_numpy().reshape(-1, 1)
apparant_temp = df['Apparent Temperature (C)'].to_numpy().reshape(-1, 1)
humidity = df['Humidity'].to_numpy().reshape(-1, 1)

# %%
plt.scatter(temperature, apparant_temp)
plt.grid()
plt.xlabel('Temperature (C)')
plt.ylabel('Apparent Temperature (C)')
# Out:
# Text(0, 0.5, 'Apparent Temperature (C)')

# %%
plt.scatter(humidity, temperature)
plt.grid()
plt.xlabel('Humidity')
plt.ylabel('Temperature (C)')
# Out:
# Text(0, 0.5, 'Temperature (C)')

# %% [markdown]
# ## Temperature and Apparent Temperature

# %%
#type your code here:
temp = df["Temperature (C)"]
app_temp = df["Apparent Temperature (C)"]
covariance1=np.cov(temp,app_temp)

correlation1= np.corrcoef(temp,app_temp)
print("Covariance: \n", covariance1)
print("Correlation: \n", correlation1)
# Out:
# Covariance:
#  [[ 91.23203712 101.41828319]
#  [101.41828319 114.42254413]]
# Correlation:
#  [[1.         0.99262856]
#  [0.99262856 1.        ]]

# %% [markdown]
# ## Temperature and Humidity

# %%
#type your code here:
temp = df["Temperature (C)"]
humidity = df["Humidity"]
covariance2=np.cov(temp,humidity)

correlation2= np.corrcoef(temp,humidity)
print("Covariance: \n", covariance2)
print("Correlation: \n", correlation2)
# Out:
# Covariance:
#  [[ 9.12320371e+01 -1.18046179e+00]
#  [-1.18046179e+00  3.82095917e-02]]
# Correlation:
#  [[ 1.         -0.63225468]
#  [-0.63225468  1.        ]]
